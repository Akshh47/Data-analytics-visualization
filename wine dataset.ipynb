# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
from  plotly.offline import iplot
import plotly as py 
import plotly.tools as tls 
 
# %matplotlib inline

# %%
import plotly as py

# %%
import cufflinks as cf

# %%
import scipy.stats as stats

# %%
import scipy.stats as stats

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
de3=pd.read_csv('https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv')

# %%
de3.head(2)
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050

# %%
de3.shape
# Out:
# (178, 14)

# %%
de3.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
de3.duplicated().sum()
# Out:
# 0

# %%
de3['Wine'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
de3['Alcohol'].unique()
# Out:
# array([14.23, 13.2 , 13.16, 14.37, 13.24, 14.2 , 14.39, 14.06, 14.83,
#        13.86, 14.1 , 14.12, 13.75, 14.75, 14.38, 13.63, 14.3 , 13.83,
#        14.19, 13.64, 12.93, 13.71, 12.85, 13.5 , 13.05, 13.39, 13.3 ,
#        13.87, 14.02, 13.73, 13.58, 13.68, 13.76, 13.51, 13.48, 13.28,
#        13.07, 14.22, 13.56, 13.41, 13.88, 14.21, 13.9 , 13.94, 13.82,
#        13.77, 13.74, 13.29, 13.72, 12.37, 12.33, 12.64, 13.67, 12.17,
#        13.11, 13.34, 12.21, 12.29, 13.49, 12.99, 11.96, 11.66, 13.03,
#        11.84, 12.7 , 12.  , 12.72, 12.08, 12.67, 12.16, 11.65, 11.64,
#        12.69, 11.62, 12.47, 11.81, 12.6 , 12.34, 11.82, 12.51, 12.42,
#        12.25, 12.22, 11.61, 11.46, 12.52, 11.76, 11.41, 11.03, 12.77,
#        11.45, 11.56, 11.87, 12.07, 12.43, 11.79, 12.04, 12.86, 12.88,
#        12.81, 12.53, 12.84, 13.36, 13.52, 13.62, 12.87, 13.32, 13.08,
#        12.79, 13.23, 12.58, 13.17, 13.84, 12.45, 14.34, 12.36, 13.69,
# ...

# %%
sns.countplot(data=de3,x='Alcohol')
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='count'>

# %%
sns.countplot(data=de3,x='Wine')
# Out:
# <AxesSubplot:xlabel='Wine', ylabel='count'>

# %%
de3.corr()
# Out:
#                           Wine   Alcohol  Malic.acid       Ash       Acl  \
# Wine                  1.000000 -0.328222    0.437776 -0.049643  0.517859
# Alcohol              -0.328222  1.000000    0.094397  0.211545 -0.310235
# Malic.acid            0.437776  0.094397    1.000000  0.164045  0.288500
# Ash                  -0.049643  0.211545    0.164045  1.000000  0.443367
# Acl                   0.517859 -0.310235    0.288500  0.443367  1.000000
# Mg                   -0.209179  0.270798   -0.054575  0.286587 -0.083333
# Phenols              -0.719163  0.289101   -0.335167  0.128980 -0.321113
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077 -0.351370
# Nonflavanoid.phenols  0.489109 -0.155929    0.292977  0.186230  0.361922
# Proanth              -0.499130  0.136698   -0.220746  0.009652 -0.197327
# Color.int             0.265668  0.546364    0.248985  0.258887  0.018732
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667 -0.273955
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(de3.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.scatterplot(data=de3, x='Wine',y='Alcohol',hue='Alcohol',alpha =0.6)
# Out:
# <AxesSubplot:xlabel='Wine', ylabel='Alcohol'>

# %%
de3['Wine'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Wine, dtype: int64
